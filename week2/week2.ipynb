# %%
import pandas as pd
new_series= pd.Series([5,6,7,8,9,10], index=['a','b','c','d','e','f'])
print(new_series)
print('_____________')
print(new_series.values)
print('_____________')
print(new_series['f'])
# Out:
# a     5
# b     6
# c     7
# d     8
# e     9
# f    10
# dtype: int64
# _____________
# [ 5  6  7  8  9 10]
# _____________
# 10

# %%
import pandas as pd

df = pd.DataFrame({
    'Country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
    'Population': [7.04, 143.5, 9.5, 45.5],
    'Square': [2724902, 17125191, 207600, 603628]
})

print(df.columns)
print('_____________________')
print(df.index)
# Out:
# Index(['Country', 'Population', 'Square'], dtype='object')
# _____________________
# RangeIndex(start=0, stop=4, step=1)

# %%
import pandas as pd

df = pd.DataFrame({
    'Country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
    'Population': [17.04, 143.5, 9.5, 45.5],
    'Square': [2724902, 17125191, 207600, 603628],
})

print(df)
print('_____________________')

df.index = ['KZ', 'RU', 'BY', 'UA']
df.index.name = 'Country Code'
print(df)
# Out:
#       Country  Population    Square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600
# 3     Ukraine       45.50    603628
# _____________________
#                  Country  Population    Square
# Country Code
# KZ            Kazakhstan       17.04   2724902
# RU                Russia      143.50  17125191
# BY               Belarus        9.50    207600
# UA               Ukraine       45.50    603628

# %%
from matplotlib import pyplot as plt
plt.hist(y)
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.legend(loc='lower right')
plt.title('Company Sales data of last year')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()
y = [10,5,8,4,2]
plt.hist(y)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
df = pd.DataFrame(np.arange(20).reshape(5,4), columns=['A', 'B', 'C', 'D'])
print(df)
# Out:
#     A   B   C   D
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15
# 4  16  17  18  19

# %%
import numpy as np
from scipy.sparse import csr_matrix
arr = np.array([[0,0,0],[0,0,1],[1,0,2]])
newarr = csr_matrix(arr).tocsc()
print(newarr)
# Out:
#   (2, 0)	1
#   (1, 2)	1
#   (2, 2)	2

# %%
import numpy as np
from scipy.sparse import csr_matrix
arr = np.array([0,0,1,0,0,1,1,0,2])
print(csr_matrix(arr))
# Out:
#   (0, 2)	1
#   (0, 5)	1
#   (0, 6)	1
#   (0, 8)	2

# %%
#question 1
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[5,6,7,8]
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
plt.yticks([0,5,6,7,8])
ax.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Title')
plt.show()

# %%
#question 2
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,.2,.2])
ax1.plot(x,y)
ax2.plot(x,y)
plt.show()

# %%
#question 3
df=pd.read_csv('company_sales_data.csv')
y=df['total_profit']
x=df['month_number']
x=x.tolist()
y=y.tolist()
plt.plot(x,y)
plt.xlabel('month')
plt.ylabel('profit')
plt.show()

# %%
#question 4
plt.plot(x,y, linestyle='dotted', color='red', label='Profit', marker='o', markerfacecolor='red', markersize=8, linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Sold Units Number')
plt.legend(loc='lower right')
plt.show()
